# %%
1) Vamos criar aos pouquinhos uma classe Evento que registra eventos de um 
calendário. Pra começar, nessa questão você deve:  
○ Criar uma classe chamada Evento  
○ Adicionar um atributo de classe total_eventos que será usado para 
contar o número total de eventos (instâncias de classe) criadas. ○ 
Implemente o método construtor que deve receber os parâmetros 
titulo (string), data_hora (datetime), descrição (string). Crie e 
inicialize um atributo de instância para cada um dos parâmetros citados.  
○ O construtor também deve inicializar um atributo de instância 
is_concluido = False. Esse atributo será utilizado mais à frente. ○ 
No construtor você também deve incrementar o atributo de classe 
total_eventos em 1 a cada nova instância criada.  
Teste o seu código criando duas diferentes instâncias de evento (preencha os 
atributos como quiser) e imprimindo todos os seus atributos (de classe e de 
instância).  
Consulte este tutorial biblioteca datetime caso não esteja familiarizado.

# %%
from datetime import datetime

class Evento:
    # Atributo de classe
    total_eventos = 0

    def __init__(self, titulo: str, data_hora: datetime, descricao: str):
        # Atributos de instância
        self.titulo = titulo
        self.data_hora = data_hora
        self.descricao = descricao
        self.is_concluido = False

        # Incrementa o total de eventos
        Evento.total_eventos += 1

# %%
# Criando duas instâncias de Evento
evento1 = Evento(
    "Reunião de Projeto",
    datetime(2026, 4, 1, 14, 30),
    "Discussão sobre o andamento do projeto"
)

evento2 = Evento(
    "Consulta Médica",
    datetime(2026, 4, 2, 9, 0),
    "Consulta anual de rotina"
)

# Imprimindo atributos do evento1
print("Evento 1:")
print("Título:", evento1.titulo)
print("Data/Hora:", evento1.data_hora)
print("Descrição:", evento1.descricao)
print("Concluído:", evento1.is_concluido)

print("\nEvento 2:")
print("Título:", evento2.titulo)
print("Data/Hora:", evento2.data_hora)
print("Descrição:", evento2.descricao)
print("Concluído:", evento2.is_concluido)

# Imprimindo atributo de classe
print("\nTotal de eventos criados:", Evento.total_eventos)
# Out:
# Evento 1:
# Título: Reunião de Projeto
# Data/Hora: 2026-04-01 14:30:00
# Descrição: Discussão sobre o andamento do projeto
# Concluído: False
#
# Evento 2:
# Título: Consulta Médica
# Data/Hora: 2026-04-02 09:00:00
# Descrição: Consulta anual de rotina
# Concluído: False
#
# Total de eventos criados: 2

# %%
from datetime import datetime

class Evento:
    total_eventos = 0

    def __init__(self, titulo: str, data_hora: datetime, descricao: str):
        self.titulo = titulo
        self.data_hora = data_hora
        self.descricao = descricao
        self.is_concluido = False

        Evento.total_eventos += 1

    # ✅ Método de instância
    def isConcluido(self):
        if self.data_hora < datetime.now():
            self.is_concluido = True

    # ✅ Método de classe
    @classmethod
    def num_eventos(cls):
        return cls.total_eventos

    # ✅ Método estático
    @staticmethod
    def valida_evento(titulo, data_hora, descricao):
        return (
            isinstance(titulo, str) and
            isinstance(data_hora, datetime) and
            isinstance(descricao, str)
        )

    # ✨ Método mágico __str__
    def __str__(self):
        return f"Evento: {self.titulo}, Data: {self.data_hora}, Descrição: {self.descricao}, Concluido: {self.is_concluido}"

    # ✨ Métodos de comparação (baseados em data_hora)
    def __eq__(self, other):
        return self.data_hora == other.data_hora

    def __ne__(self, other):
        return self.data_hora != other.data_hora

    def __lt__(self, other):
        return self.data_hora < other.data_hora

    def __le__(self, other):
        return self.data_hora <= other.data_hora

    def __gt__(self, other):
        return self.data_hora > other.data_hora

    def __ge__(self, other):
        return self.data_hora >= other.data_hora

# %%
evento_passado = Evento(
    "Evento Antigo",
    datetime(2020, 1, 1, 10, 0),
    "Já aconteceu"
)

evento_passado.isConcluido()
print("Concluído?", evento_passado.is_concluido)
# Out:
# Concluído? True

# %%
print("Total de eventos:", Evento.num_eventos())
# Out:
# Total de eventos: 1

# %%
# Valores corretos
print(Evento.valida_evento(
    "Teste",
    datetime.now(),
    "Descrição válida"
))

# Valores incorretos
print(Evento.valida_evento(
    123,
    "data errada",
    []
))
# Out:
# True
# False

# %%
# Valores corretos
print(Evento.valida_evento(
    "Teste",
    datetime.now(),
    "Descrição válida"
))

# Valores incorretos
print(Evento.valida_evento(
    123,
    "data errada",
    []
))
# Out:
# True
# False

# %%
evento1 = Evento(
    "Evento 1",
    datetime(2026, 5, 1, 10, 0),
    "Primeiro evento"
)

evento2 = Evento(
    "Evento 2",
    datetime(2026, 6, 1, 10, 0),
    "Segundo evento"
)

# Testando __str__
print(evento1)
print(evento2)

# Comparações
print("==", evento1 == evento2)
print("!=", evento1 != evento2)
print("<", evento1 < evento2)
print("<=", evento1 <= evento2)
print(">", evento1 > evento2)
print(">=", evento1 >= evento2)
# Out:
# Evento: Evento 1, Data: 2026-05-01 10:00:00, Descrição: Primeiro evento, Concluido: False
# Evento: Evento 2, Data: 2026-06-01 10:00:00, Descrição: Segundo evento, Concluido: False
# == False
# != True
# < True
# <= True
# > False
# >= False
